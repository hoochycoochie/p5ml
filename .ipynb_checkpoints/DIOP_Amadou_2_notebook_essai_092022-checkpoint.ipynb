# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer, InterclusterDistance
from sklearn.cluster import KMeans

# %%
df=pd.read_csv('data/cleaned_and_normalized_pca_category.csv')

# %%
df.shape
# Out:
# (94088, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94088 entries, 0 to 94087
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pca_0   94088 non-null  float64
# dtypes: float64(1)
# memory usage: 735.2 KB

# %%
df.head()
# Out:
#         pca_0
# 0 -126.627926
# 1 -123.639132
# 2  298.950353
# 3   82.977030
# 4   50.007440

# %% [markdown]
# ## Partie 1 Clustering avec Kmeans

# %%
cats_cols =[col for col in df.columns.tolist() if col.startswith('x0')]
relevant_cols=[col for col in df.columns.tolist() if col not in ['customer_unique_id','customer_state','main_favorite_category'] and col not in cats_cols]
X = df['pca_0'].values

# %%
kmeans_visualizer = KElbowVisualizer(KMeans(),K=(2,6))
kmeans_visualizer.fit(X)
kmeans_visualizer.show()

# %%
K = kmeans_visualizer.elbow_value_
silhouette_visualizer =  SilhouetteVisualizer(KMeans(K))
silhouette_visualizer.fit(X)
silhouette_visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-c5cf15bc59fd> in <module>
#       1 K = kmeans_visualizer.elbow_value_
#       2 silhouette_visualizer =  SilhouetteVisualizer(KMeans(K))
# ----> 3 silhouette_visualizer.fit(X)
#       4 silhouette_visualizer.show()
#
# ~/anaconda3/lib/python3.7/site-packages/yellowbrick/cluster/silhouette.py in fit(self, X, y, **kwargs)
#     145         labels = self.estimator.predict(X)
#     146         self.silhouette_score_ = silhouette_score(X, labels)
# --> 147         self.silhouette_samples_ = silhouette_samples(X, labels)
#     148
#     149         # Draw the silhouette figure
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     231         _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     232     )
# ...

# %%
distance_visualizer = InterclusterDistance(KMeans(K))
distance_visualizer.fit(X)
distance_visualizer.show()
